# %%
list = []
num = int(input('How many numbers you want to Enter : '));
for n in range(num):
    numbers = int(input('Enter number '));
    list.append(numbers);
print("Sum of elements in given list is :", sum(list));
# Out:
# How many numbers you want to Enter : 5
# Enter number 10
# Enter number 12
# Enter number 10
# Enter number 5
# Enter number 3
# Sum of elements in given list is : 40
