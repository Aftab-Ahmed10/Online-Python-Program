# %%
num = int(input("Enter the number : "));

if (num % 2) == 0:  
   print("{0} is Even Number".format(num)); 
else:  
   print("{0} is Odd Number".format(num));
# Out:
# Enter the number : 13
# 13 is Odd Number
